# %%
# Experiment to generate and visually inspect the quality
# of synthesized breast invasive carcinoma gene expression samples

# %%
from IPython.display import Image

# %%
# Experimental schematic, 2D convolutional layer VAE
# Pre-train on bladder cancer gene expression
# Fine-tune on breast invasive carcinoma, 50% samples
# Send raw training samples, decoded synthetic samples, and held-out samples 
    # to UMAP dimensionality reducer / plot for comparison
Image(filename='UMAP_new_gen_BRCA_held_out_val.drawio.png')
